# %% [markdown]
# <a href="https://colab.research.google.com/github/Papop-San/Classification_spam/blob/main/Model_Classification_Spam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Libary Section


import pandas as pd
import numpy as np
import string
import seaborn as sns
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from collections import Counter
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import GridSearchCV
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data_sets/data_normal.xls')

# %%
#Rename
# on the file I just adding the header already

data.columns = ['label' , 'messages']

# %%
data.describe()
# Out:
#        label                messages
# count   5573                    5573
# unique     2                    5170
# top      ham  Sorry, I'll call later
# freq    4826                      30
